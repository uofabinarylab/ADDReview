# %%
import matplotlib.pyplot as plt

papers = []
features = []
# Parse the data from the table
table_data = [
    ('Jitter', '1, Vicsi (2012);1, Alghowinem and Goecke(2013);-1, Quatieri and Malyska (2012);0, Quatieri and Malyska (2012);1, Horwitz et al (2013);1, Kiss et al (2017);'),
    ('Shimmer', '1, Vicsi (2012);-1, Alghowinem and Goecke(2013);1, Quatieri and Malyska (2012);1, Horwitz et al. (2013);1, Kiss et al. (2017);'),

    ('HNR', '1, Alghowinem and Goecke(2013);0, Horwitz et al. (2013); 0, Vicsi et al. (2012);1, Quatieri and Malyska (2012);'),
    ('QOQ', '-1, Scherer and Stratou(2013)'),
    ('NAQ', '-1, Scherer and Stratou(2013)'),
    ('Peak slope', '1, Scherer and Stratou(2013)'),
    ('F1 mean', '-1, Vicsi (2012);-1, Kiss and Vicsi(2017);0, Mundt et al. (2012);'),
    ('F2 mean', '-1, Vicsi (2012); 1, Kiss and Vicsi(2017)'),
    ('F2 variability', '1, Kiss and Vicsi(2017)'),
    ('MFCC', '1, Kiss and Vicsi(2017);1, Kiss and Vicsi(2017);1, Kiss and Vicsi(2017);'),
    ('f0 mean', '-1, Kiss and Vicsi(2012); -1, Shin and Cho(2021);'),
    ('f0 variability', '-1, Yang and Fairbairn(2013); -1, Kiss and Vicsi(2012);'),
    ('Intensity mean', '-1, Yang and Fairbairn(2013); -1, Kiss and Vicsi(2012);'),
    ('Intensity variability', '-1, Kiss and Vicsi(2017)'),
    ('Energy variance', '-1, Cummins and Epps(2013);'),
    ('Speech rate', '-1, Kiss and Vicsi(2017);-1, Harati and Shriberg(2019);-1, Tao and Esposito(2020)'),
    ('Pause duration mean', '1, Tao and Esposito(2020)'),
    ('Pause rate', '1, Tao and Esposito(2020)'),
    ('Pauses total', '1, Tao and Esposito(2020)'),
    ('SkewnessMFCC1', '1, Fraser and Rudzicz(2016)'),
    ('MeanΔΔMFCC8', '1, Fraser and Rudzicz(2016)'),
    ('KurtosisMFCC4', '1, Fraser and Rudzicz(2016)'),
    ('KurtosisMFCC3', '1, Fraser and Rudzicz(2016)'),
    ('KurtosisΔMFCC2', '1, Fraser and Rudzicz(2016)'),
    ('SkewnessΔΔMFCC2', '1, Fraser and Rudzicz(2016)'),
    ('KurtosisMFCC10', '1, Fraser and Rudzicz(2016)')
]

for feature, paper_list in table_data:
    if paper_list != '':
        papers.extend([paper.split(',')[1].strip() if ',' in paper else paper for paper in paper_list.split(';')])
        features.extend([feature] * len(paper_list.split(';')))

plt.scatter(papers, features, s=100)
plt.xlabel('Papers')
plt.ylabel('Features')
plt.title('Acoustic Features and Depression')
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt

papers = []
features = []
colors = []

table_data = [
    ('Jitter', '1, Vicsi (2012);1, Alghowinem and Goecke(2013);-1, Quatieri and Malyska (2012);0, Quatieri and Malyska (2012);1, Horwitz et al (2013);1, Kiss et al (2017);'),
    ('Shimmer', '1, Vicsi (2012);-1, Alghowinem and Goecke(2013);1, Quatieri and Malyska (2012);1, Horwitz et al. (2013);1, Kiss et al. (2017);'),
    ('Tremor', ''),
    ('HNR', '1, Alghowinem and Goecke(2013);0, Horwitz et al. (2013); 0, Vicsi et al. (2012);1, Quatieri and Malyska (2012);'),
    ('FDR', ''),
    ('ADR', ''),
    ('QOQ', '-1, Scherer and Stratou(2013)'),
    ('NAQ', '-1, Scherer and Stratou(2013)'),
    ('Peak slope', '1, Scherer and Stratou(2013)'),
    ('F1 mean', '-1, Vicsi (2012);-1, Kiss and Vicsi(2017);0, Mundt et al. (2012);'),
    ('F2 mean', '-1, Vicsi (2012); 1, Kiss and Vicsi(2017)'),
    ('F1 variability', ''),
    ('F2 variability', '1, Kiss and Vicsi(2017)'),
    ('F1 range', ''),
    ('Vowel space', ''),
    ('LPC', ''),
    ('MFCC', '1, Kiss and Vicsi(2017);1, Kiss and Vicsi(2017);1, Kiss and Vicsi(2017);'),
    ('f0 mean', '-1, Kiss and Vicsi(2012); -1, Shin and Cho(2021);'),
    ('f0 variability', '-1, Yang and Fairbairn(2013); -1, Kiss and Vicsi(2012);'),
    ('f0 range', ''),
    ('Intensity mean', '-1, Yang and Fairbairn(2013); -1, Kiss and Vicsi(2012);'),
    ('Intensity variability', '-1, Kiss and Vicsi(2017)'),
    ('Energy variance', '-1, Cummins and Epps(2013);'),
    ('Energy velocity', ''),
    ('Maximum phonation time', ''),
    ('Speech rate', '-1, Kiss and Vicsi(2017);-1, Harati and Shriberg(2019);-1, Tao and Esposito(2020)'),
    ('Articulation rate', ''),
    ('Time talking', ''),
    ('Utterance duration mean', ''),
    ('Pause duration mean', '1, Tao and Esposito(2020)'),
    ('Pause variability', ''),
    ('Pause rate', '1, Tao and Esposito(2020)'),
    ('Pauses total', '1, Tao and Esposito(2020)'),
    ('SkewnessMFCC1', '1, Fraser and Rudzicz(2016)'),
    ('MeanΔΔMFCC8', '1, Fraser and Rudzicz(2016)'),
    ('KurtosisMFCC4', '1, Fraser and Rudzicz(2016)'),
    ('KurtosisMFCC3', '1, Fraser and Rudzicz(2016)'),
    ('KurtosisΔMFCC2', '1, Fraser and Rudzicz(2016)'),
    ('SkewnessΔΔMFCC2', '1, Fraser and Rudzicz(2016)'),
    ('KurtosisMFCC10', '1, Fraser and Rudzicz(2016)')
]

for feature, paper_list in table_data:
    if paper_list != '':
        papers.extend([paper.split(',')[1].strip() if ',' in paper else paper for paper in paper_list.split(';')])
        features.extend([feature] * len(paper_list.split(';')))
        for paper in paper_list.split(';'):
            value = paper.split(',')[0].strip()
            if value == '1':
                colors.append('red')
            elif value == '0':
                colors.append('grey')
            else:
                colors.append('blue')

plt.scatter(papers, features, c=colors, s=100)
# plt.xlabel('Papers')
# plt.ylabel('Features')
# plt.title('Acoustic Features and Depression')
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# # Acoustic

# %%
import matplotlib.pyplot as plt

papers = []
features = []
colors = []

table_data = [
    ('Jitter', '1, Vicsi (2012);1, Alghowinem and Goecke(2013);-1, Quatieri and Malyska (2012);0, Quatieri and Malyska (2012);1, Horwitz et al (2013);1, Kiss et al (2017)'),
    ('Shimmer', '1, Vicsi (2012);-1, Alghowinem and Goecke(2013);1, Quatieri and Malyska (2012);1, Horwitz et al. (2013);1, Kiss et al. (2017)'),
    ('HNR', '1, Alghowinem and Goecke(2013);0, Horwitz et al. (2013); 0, Vicsi et al. (2012);1, Quatieri and Malyska (2012)'),
    ('QOQ', '-1, Scherer and Stratou(2013)'),
    ('NAQ', '-1, Scherer and Stratou(2013)'),
    ('Peak slope', '1, Scherer and Stratou(2013)'),
    ('F1 mean', '-1, Vicsi (2012);-1, Kiss and Vicsi(2017);0, Mundt et al. (2012)'),
    ('F2 mean', '-1, Vicsi (2012); 1, Kiss and Vicsi(2017)'),
    ('F2 variability', '1, Kiss and Vicsi(2017)'),
    ('MFCC', '1, Kiss and Vicsi(2017);1, Kiss and Vicsi(2017);1, Kiss and Vicsi(2017)'),
    ('f0 mean', '-1, Kiss and Vicsi(2012); -1, Shin and Cho(2021)'),
    ('f0 variability', '-1, Yang and Fairbairn(2013); -1, Kiss and Vicsi(2012)'),
    ('Intensity mean', '-1, Yang and Fairbairn(2013); -1, Kiss and Vicsi(2012)'),
    ('Intensity variability', '-1, Kiss and Vicsi(2017)'),
    ('Energy variance', '-1, Cummins and Epps(2013)'),
    ('Speech rate', '-1, Kiss and Vicsi(2017);-1, Harati and Shriberg(2019);-1, Tao and Esposito(2020)'),
    ('Pause duration mean', '1, Tao and Esposito(2020)'),
    ('Pause rate', '1, Tao and Esposito(2020)'),
    ('Pauses total', '1, Tao and Esposito(2020)'),
    ('SkewnessMFCC1', '1, Fraser and Rudzicz(2016)'),
    ('MeanΔΔMFCC8', '1, Fraser and Rudzicz(2016)'),
    ('KurtosisMFCC4', '1, Fraser and Rudzicz(2016)'),
    ('KurtosisMFCC3', '1, Fraser and Rudzicz(2016)'),
    ('KurtosisΔMFCC2', '1, Fraser and Rudzicz(2016)'),
    ('SkewnessΔΔMFCC2', '1, Fraser and Rudzicz(2016)'),
    ('KurtosisMFCC10', '1, Fraser and Rudzicz(2016)')
]

for feature, paper_list in table_data:
    if paper_list != '':
#         print([paper.split(',')[1].strip() if ',' in paper else paper for paper in paper_list.split(';')])
        papers.extend([paper.split(',')[1].strip() if ',' in paper else paper for paper in paper_list.split(';')])
        features.extend([feature] * len(paper_list.split(';')))
        for paper in paper_list.split(';'):
            value = paper.split(',')[0].strip()
            if value == '1':
                colors.append('red')
            elif value == '0':
                colors.append('grey')
            else:
                colors.append('blue')

plt.scatter(papers, features, s=50, c=colors)
# plt.xlabel('Papers')
# plt.ylabel('Acoustic features')
# plt.title('Acoustic Features and Depression')
plt.xticks(rotation=90)

ax = plt.gca()
blue = 'dodgerblue'
red = 'firebrick'
colors = [blue] * 6 + [red] * 3 + ['purple'] + ['k']*16
for xtick, color in zip(ax.get_yticklabels(), colors):
#     print(xtick)
    xtick.set_color(color)

# Create custom legend
legend_elements = [
    plt.Line2D([0], [0], marker='o', color='red', label='Positively correlated'),
    plt.Line2D([0], [0], marker='o', color='grey', label='Nonsignificant'),
    plt.Line2D([0], [0], marker='o', color='blue', label='Negatively Correlated')
]
plt.legend(handles=legend_elements, loc='upper left')
plt.savefig('./acoustic.eps', format='eps', bbox_inches="tight")
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # Semantic

# %%
import matplotlib.pyplot as plt

papers = []
features = []
colors = []

table_data = [
    ('Time spent on social media', '1, Keles (2020);1, Vidal (2020);1, Cunningham (2021);1, Zhong (2021);1, Aragón (2019);1, Ford (2019);1, Peng (2019);1, Shensa ( 2017);1, Primack (2018);1, Kircaburun (2016);1, Puukko (2020)'),
    ('BERT Embedding', '0, Zogan (2021); 0, Lin (2021); 0, Cha ( 2022)'),
    ('Bag of Sub-Emotions (BoSE)', '0, Aragón (2019)'),
    ('Average number of words', '-1, Hu (2015); -1, Liaw (2022)'),
    ('Number of mentions', '-1, Hu (2015)'),
    ('Update frequency', '-1, Hu (2015)'),
    ('Use of 1st person pronouns', '-1, Kelley (2022); -1, Ramiandrisoa (2020)'),
    ('Use of swear words', '1, Kelley (2022)'),
    ('Word embeddings', '0, Figuerêdo (2022); 0, Stankevich (2018); 0, Lara (2021); 0, Kumnunt (2020);  0, Zogan (2023); 0, Cha (2022)'),
    ('Linguistic Inquiry and Word Count', '0, Mann (2019);0, Tadesse (2019);0, Skaik (2020); 0, Hussain (2020)'),
]

for feature, paper_list in table_data:
    if paper_list != '':
#         print([paper.split(',')[1].strip() if ',' in paper else paper for paper in paper_list.split(';')])
        papers.extend([paper.split(',')[1].strip() if ',' in paper else paper for paper in paper_list.split(';')])
        features.extend([feature] * len(paper_list.split(';')))
        for paper in paper_list.split(';'):
            value = paper.split(',')[0].strip()
            if value == '1':
                colors.append('red')
            elif value == '0':
                colors.append('grey')
            else:
                colors.append('blue')

plt.scatter(papers, features, s=50, c=colors)
# plt.xlabel('Papers')
# plt.ylabel('Semantic features')
# plt.title('Acoustic Features and Depression')
plt.xticks(rotation=90)

ax = plt.gca()
# blue = 'dodgerblue'
# red = 'firebrick'
# colors = [blue] * 6 + [red] * 3 + ['purple'] + ['k']*16
# for xtick, color in zip(ax.get_yticklabels(), colors):
# #     print(xtick)
#     xtick.set_color(color)

# Create custom legend
legend_elements = [
    plt.Line2D([0], [0], marker='o', color='red', label='Positively correlated'),
    plt.Line2D([0], [0], marker='o', color='grey', label='Not reported'),
    plt.Line2D([0], [0], marker='o', color='blue', label='Negatively Correlated')
]
plt.legend(handles=legend_elements, loc='upper left')
    
plt.savefig('./semantic.eps', format='eps', bbox_inches="tight")
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # Visual

# %%
import matplotlib.pyplot as plt

papers = []
features = []
colors = []

table_data = [
    ('Speed and accuracy of \n negative facial expression recognition', '-1, Ma (2021); -1, Liu (2021)'),
    ('Facial action units-AU12', '-1, Girard (2013)'),
    ('Facial action units-AU14)', '-1, Girard (2013)'),
    ('Facial action units-AU15', '-1, Girard (2013)'),
    ('Pupil movement', '-1, Hamid (2023)'),
    ('Distances across left and right eye brows', '-1, Hamid (2023)'),
    ('Points at the corners of mouth', '-1, Hamid (2023)'),
    ('Local binary pattern', '0, Dadiz (2019)'),
    ('Right nose (speed)', '-1, Sumali (2019)'),
]

for feature, paper_list in table_data:
    if paper_list != '':
#         print([paper.split(',')[1].strip() if ',' in paper else paper for paper in paper_list.split(';')])
        papers.extend([paper.split(',')[1].strip() if ',' in paper else paper for paper in paper_list.split(';')])
        features.extend([feature] * len(paper_list.split(';')))
        for paper in paper_list.split(';'):
            value = paper.split(',')[0].strip()
            if value == '1':
                colors.append('red')
            elif value == '0':
                colors.append('grey')
            else:
                colors.append('blue')

plt.scatter(papers, features, s=50, c=colors)
# plt.xlabel('Papers')
# plt.ylabel('Visual features')
# plt.title('Acoustic Features and Depression')
plt.xticks(rotation=90)

ax = plt.gca()
# blue = 'dodgerblue'
# red = 'firebrick'
# colors = [blue] * 6 + [red] * 3 + ['purple'] + ['k']*16
# for xtick, color in zip(ax.get_yticklabels(), colors):
# #     print(xtick)
#     xtick.set_color(color)

# Create custom legend
legend_elements = [
    plt.Line2D([0], [0], marker='o', color='red', label='Positively correlated'),
    plt.Line2D([0], [0], marker='o', color='grey', label='Not reported'),
    plt.Line2D([0], [0], marker='o', color='blue', label='Negatively Correlated')
]
plt.legend(handles=legend_elements, loc='upper left')
    
plt.savefig('./visual.eps', format='eps', bbox_inches="tight")

plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
